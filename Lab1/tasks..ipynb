# %% [markdown]
# Name: Muhammad Bilal
# Reg No: FA23-BAI-029

# %% [markdown]
# ### Task 1: Variables and Basic Operators

# %% [markdown]
# This task demonstrates variable creation, printing data types, using arithmetic operators, comparison operators, and swapping variables.

# %%
name, roll_no, cgpa = "Alice", 101, 3.8
print(name, type(name))
print(roll_no, type(roll_no))
print(cgpa, type(cgpa))

marks1, marks2 = 80, 90
marks1 += 5
marks2 -= 3
print(marks1, marks2)

print(marks1 == marks2)
print(marks1 > marks2)

print("Before:", marks1, marks2)
marks1, marks2 = marks2, marks1
print("After:", marks1, marks2)

# %% [markdown]
# ### Task 2: Working with Lists

# %% [markdown]
# This task focuses on list operations like appending, inserting, removing, popping, sorting, and getting list length.

# %%
favorite_subjects = ["Math", "Physics", "Chemistry", "English", "History"]
favorite_subjects.append("Biology")
favorite_subjects.insert(2, "Computer Science")
favorite_subjects.remove("English")
favorite_subjects.pop()
favorite_subjects.sort()
print(favorite_subjects, len(favorite_subjects))

# %% [markdown]
# ### Task 3: Tuples and Dictionaries

# %% [markdown]
# This task shows how tuples are immutable, how to catch assignment errors, and how to create and modify dictionary key-value pairs.

# %%
weekdays = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday")
try:
    weekdays[1] = "Funday"
except TypeError as e:
    print(f"Error: {e}")

subject_credits = {"AIC380": 3, "CS101": 4, "MATH201": 3, "PHY102": 4}
subject_credits["AIC380"] = 4
subject_credits["BIO101"] = 3
print(subject_credits)

# %% [markdown]
# ### Task 4: Indexing and Slicing Practice

# %% [markdown]
# This task practices range-based list generation, index slicing, stepping, and reversing arrays without using built-in functions.

# %%
numbers = list(range(1, 16))
print(numbers[:4], numbers[-4:])
print(numbers[0::3])
print(numbers[::-1])

# %% [markdown]
# ### Task 5: String Processing

# %% [markdown]
# This task demonstrates basic string processing, splitting names, f-string formatting, counting vowels, and checking case equality.

# %%
full_name = "John Doe"
first_name, last_name = full_name.split()
print(f"My first name is {first_name} and my last name is {last_name}.")

vowels_count = sum(1 for char in full_name.lower() if char in "aeiou")
print(vowels_count)

print(full_name.upper() == full_name.lower())

# %% [markdown]
# ### Task 6: Conditional Statements

# %% [markdown]
# This task shows conditional logic using standard if/elif/else blocks, nested conditions, and logical combination operators.

# %%
marks = 85
if marks >= 90: print("A")
elif marks >= 80: print("B")
elif marks >= 70: print("C")
elif marks >= 60: print("D")
else: print("F")

num = -5
if num > 0: print("Positive")
elif num < 0: print("Negative")
else: print("Zero")

year = 2024
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0: print("Leap Year")
        else: print("Not Leap Year")
    else: print("Leap Year")
else: print("Not Leap Year")

cgpa, attendance = 3.6, 85
if cgpa > 3.5 and attendance > 80: print("Eligible")
else: print("Not Eligible")

# %% [markdown]
# ### Task 7: Loops with Break and Continue

# %% [markdown]
# This task covers loop control syntax, including skip actions using continue, exit commands using break, while loops, and range aggregations.

# %%
for i in range(1, 31):
    if i % 4 == 0: continue
    print(i, end=" ")
print()

for i in range(1, 51):
    if i > 20: break
    print(i, end=" ")
print()

n = 5
i = 1
while i <= 10:
    print(f"{n} x {i} = {n*i}")
    i += 1

print(sum(i for i in range(1, 101) if i % 2 == 0))

# %% [markdown]
# ### Task 8: Functions – Basics

# %% [markdown]
# This task introduces Python functions with default parameters, boolean return operations, and illustrates passing mutable objects by reference.

# %%
def calculate_area(length, width=1):
    return length * width

print(calculate_area(5, 3))
print(calculate_area(5))
area_val = calculate_area(10, 2)
print(area_val)

def is_even(number):
    return number % 2 == 0

def add_item(lst):
    lst.append("new_item")

my_list = [1, 2, 3]
print("Before:", my_list)
add_item(my_list)
print("After:", my_list)

# %% [markdown]
# ### Task 9: Classes and Inheritance

# %% [markdown]
# This task illustrates object-oriented programming, defining classes, calling methods, and inheriting and extending parent classes using super().

# %%
class Course:
    def __init__(self, course_name, credit_hours):
        self.course_name = course_name
        self.credit_hours = credit_hours
    def display_info(self):
        print(self.course_name, self.credit_hours)

c1 = Course("AIC380", 3)
c2 = Course("CS101", 4)
c1.display_info()
c2.display_info()

class LabCourse(Course):
    def __init__(self, course_name, credit_hours, lab_hours):
        super().__init__(course_name, credit_hours)
        self.lab_hours = lab_hours
    def display_info(self):
        super().display_info()
        print(self.lab_hours)

lc = LabCourse("PHY102", 4, 3)
lc.display_info()
